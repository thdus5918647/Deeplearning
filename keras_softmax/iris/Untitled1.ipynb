# %%
import pandas as pd
data = pd.read_csv('iris.csv',encoding='latin1')

print(len(data))
print(data[:5])
# Out:
# 150
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
print('품종 종류: ', data["Name"].unique(), sep="\n")
# Out:
# 품종 종류:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
import seaborn as sns

sns.set(style="ticks", color_codes=True)
g = sns.pairplot(data, hue="Name", palette="husl")
print(g)
# Out:
# <seaborn.axisgrid.PairGrid object at 0x7f173c5d2390>

# %%
sns.barplot(data['Name'], data['SepalWidth'], ci=None)

# %%
import matplotlib.pyplot as plt

data['Name'].value_counts().plot(kind='bar')
