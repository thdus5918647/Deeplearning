# %% [markdown]
# ### 1. basic data

# %%
import pandas as pd
import random
from imblearn.over_sampling import SMOTE
import numpy as np

# basic
path_file = pd.read_csv('./basic.csv')

hz = path_file['hz'].values
amp = path_file['ampliture'].values

hz = hz.tolist()
amp = amp.tolist()

#print(hz)
#print(amp)
print(len(hz))
print(len(amp))
# Out:
# 65536
# 65536

# %%
hz_result = []
value = 0

for i in range(0, len(hz)):
    if i % 50 < 5:
        value += hz[i]
        
        if i % 50 == 4:
            hz_result.append(value)
            value = 0

amp_result = []
value = 0

for i in range(0, len(amp)):
    if i % 50 < 5:
        value += amp[i]
        
        if i % 50 == 4:
            amp_result.append(value)
            value = 0


#w, h = 2, len(hz_result)
#Matrix = [[0 for x in range(w)] for y in range(h)]
#Matrix[0][0].append(hz_result)
#Matrix[1][1].append(amp_result)

#print(Matrix[0][0])

basic_result = [[]]
basic_result[0].append(hz_result)
print(basic_result)
# Out:
# [[[1.144409179688, 29.754638671879995, 58.3648681641, 86.9750976562, 115.58532714849999, 144.1955566407, 172.8057861328, 201.41601562500003, 230.0262451172, 258.63647460929997, 287.2467041015, 315.8569335938, 344.4671630859, 373.07739257820003, 401.6876220703, 430.2978515625, 458.9080810547, 487.51831054679997, 516.12854004, 544.73876953, 573.348999025, 601.9592285150001, 630.5694580100001, 659.1796875, 687.7899169900002, 716.4001464849999, 745.010375975, 773.62060547, 802.23083496, 830.8410644549999, 859.451293945, 888.0615234380001, 916.6717529299999, 945.28198242, 973.892211915, 1002.502441405, 1031.1126709, 1059.72290039, 1088.3331298839998, 1116.943359375, 1145.5535888660002, 1174.16381836, 1202.77404785, 1231.3842773449999, 1259.994506835, 1288.60473633, 1317.21496582, 1345.8251953120002, 1374.435424805, 1403.045654295, 1431.6558837900002, 1460.26611328, 1488.876342775, 1517.486572265, 1546.09680176, 1574.7070312500002, 1603.31726074, 1631.9274902349998, 1660.537719725, 1689.14
# ...
